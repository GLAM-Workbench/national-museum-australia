# %% [markdown]
# # Exploring object records

# %% [markdown]
# In this notebook we'll have a preliminary poke around in the `object` data harvested from the [NMA Collection API](https://www.nma.gov.au/about/our-collection/our-apis). I'll focus here on the basic shape/stats of the data, other notebooks will explore the object data over [time](explore_collection_object_over_time.ipynb) and [space](explore_objects_and_places.ipynb).
#
# If you haven't already, you'll need to [harvest the `object` data](harvest_records.ipynb) first.
#
# * [The shape of the data](#The-shape-of-the-data)
# * [Nested data](#Nested-data)
# * [The `additionalType` field](#The-additionalType-field)
# * [The `extent` field](#The-extent-field)
# * [How big is the collection?](#How-big-is-the-collection?)
# * [The biggest object?](#The-biggest-object?)

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <p>If you haven't used one of these notebooks before, they're basically web pages in which you can write, edit, and run live code. They're meant to encourage experimentation, so don't feel nervous. Just try running a few cells and see what happens!</p>
#
# <p>
#     Some tips:
#     <ul>
#         <li>Code cells have boxes around them.</li>
#         <li>To run a code cell click on the cell and then hit <b>Shift+Enter</b>. The <b>Shift+Enter</b> combo will also move you to the next cell, so it's a quick way to work through the notebook.</li>
#         <li>While a cell is running a <b>*</b> appears in the square brackets next to the cell. Once the cell has finished running the asterix will be replaced with a number.</li>
#         <li>In most cases you'll want to start from the top of notebook and work your way down running each cell in turn. Later cells might depend on the results of earlier ones.</li>
#         <li>To edit a code cell, just click on it and type stuff. Remember to run the cell once you've finished editing.</li>
#     </ul>
# </p>
#
# <p><b>Is this thing on?</b> If you can't edit or run any of the code cells, you might be viewing a static (read only) version of this notebook. Click here to <a href="https://mybinder.org/v2/gh/GLAM-Workbench/trove-newspapers/master?filepath=visualise-searches-over-time.ipynb">load a <b>live</b> version</a> running on Binder.</p>
#
# </div>

# %% [markdown]
# ## Import what we need

# %%
import pandas as pd
import math
from IPython.display import display, HTML, FileLink
from tinydb import TinyDB, Query
from pandas.io.json import json_normalize

# %% [markdown]
# ## Load the harvested data

# %%
# Load the harvested data from the json db
db = TinyDB('nma_object_db.json')
records = db.all()
Object = Query()

# %%
# Convert to a dataframe
df = pd.DataFrame(records)
df.head()
# Out:
#        id    type                                              title  \
# 0  145400  object  Wahlo and Tribal law by Kevin Gilbert, reprint...
# 1  251390  object    Pair of woven shoes made from feathers and hair
# 2  124081  object                           Pair of ceremonial shoes
# 3   21507  object                                     Grinding stone
# 4  142308  object                                'time CHange' [sic]
#
#                                                _meta     additionalType  \
# 0  {'modified': '2018-07-09', 'issued': '2011-10-...                NaN
# 1  {'modified': '2019-01-17', 'issued': '2018-04-...            [Shoes]
# 2  {'modified': '2018-12-04', 'issued': '2006-10-...                NaN
# 3  {'modified': '2018-06-19', 'issued': '2014-12-...  [Grinding stones]
# 4  {'modified': '2019-04-15', 'issued': '2012-06-...    [Compact discs]
#
#                                           collection      identifier  \
# 0                                                NaN             NaN
# 1  {'id': '5244', 'type': 'Collection', 'title': ...  2000.0014.0495
# 2  {'id': '1892', 'type': 'Collection', 'title': ...  1992.0089.0165
# 3  {'id': '2229', 'type': 'Collection', 'title': ...  1985.0288.0109
# 4  {'id': '3893', 'type': 'Collection', 'title': ...     AR00213.012
#
#                                               medium  \
# 0                                                NaN
# 1  [{'type': 'Material', 'title': 'Feather'}, {'t...
# 2         [{'type': 'Material', 'title': 'Feather'}]
# 3                                                NaN
# 4                                                NaN
#
#                                               extent  \
# 0                                                NaN
# 1  {'type': 'Measurement', 'length': 260, 'width'...
# 2  {'type': 'Measurement', 'length': 246, 'width'...
# 3                                                NaN
# 4                                                NaN
#
#                                  physicalDescription  ... isPartOf seeAlso  \
# 0                                                NaN  ...      NaN     NaN
# 1  Shoes, the soles of which are made from woven ...  ...      NaN     NaN
# 2  A pair of ceremonial shoes made with several m...  ...      NaN     NaN
# 3                                                NaN  ...      NaN     NaN
# 4  A compact disc, housed within a clear and blac...  ...      NaN     NaN
#
#   description hasVersion temporal relation hasPart location acknowledgement  \
# 0         NaN        NaN      NaN      NaN     NaN      NaN             NaN
# 1         NaN        NaN      NaN      NaN     NaN      NaN             NaN
# 2         NaN        NaN      NaN      NaN     NaN      NaN             NaN
# 3         NaN        NaN      NaN      NaN     NaN      NaN             NaN
# 4         NaN        NaN      NaN      NaN     NaN      NaN             NaN
#
#   educationalSignificance
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# ## The shape of the data

# %% [markdown]
# How many objects are there?

# %%
print('There are {:,} objects in the collection'.format(df.shape[0]))
# Out:
# There are 86,679 objects in the collection

# %% [markdown]
# Obviously not every record has a value for every field, let's create a quick count of the number of values in each field.

# %%
df.count()
# Out:
# id                         86679
# type                       86679
# title                      86463
# _meta                      86679
# additionalType             86652
# collection                 84256
# identifier                 86654
# medium                     73743
# extent                     64077
# physicalDescription        86359
# significanceStatement      32437
# creator                    25076
# spatial                    46658
# contributor                40796
# isAggregatedBy              4353
# isPartOf                   10718
# seeAlso                      467
# description                 9097
# hasVersion                 19845
# temporal                   29399
# relation                    3066
# hasPart                     2345
# location                    1364
# acknowledgement              785
# educationalSignificance      201
# dtype: int64

# %% [markdown]
# Let's express those counts as a percentage of the total number of records, and display them as a bar chart using Pandas.

# %%
# Get field counts and convert to dataframe
field_counts = df.count().to_frame().reset_index()

# Change column headings
field_counts.columns = ['field', 'count']

# Calculate proportion of the total
field_counts['proportion'] = field_counts['count'].apply(lambda x: x / df.shape[0])

# Style the results as a barchart
field_counts.style.bar(subset=['proportion'], color='#d65f5f').format({'proportion': '{:.2%}'.format})
# Out:
# <style  type="text/css" >
#     #T_6d9657ec_ba94_11e9_9856_ac87a32cd560row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_6d9657ec_ba94_11e9_9856_ac87a32cd560row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_6d9657ec_ba94_11e9_9856_ac87a32cd560row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 99.8%, transparent 99.8%);
#         }    #T_6d9657ec_ba94_11e9_9856_ac87a32cd560row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_6d9657ec_ba94_11e9_9856_ac87a32cd560row4_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_6d9657ec_ba94_11e9_9856_ac87a32cd560row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 97.2%, transparent 97.2%);
#         }    #T_6d9657ec_ba94_11e9_9856_ac87a32cd560row6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }    #T_6d9657ec_ba94_11e9_9856_ac87a32cd560row7_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 85.0%, transparent 85.0%);
#         }    #T_6d9657ec_ba94_11e9_9856_ac87a32cd560row8_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 73.9%, transparent 73.9%);
#         }    #T_6d9657ec_ba94_11e9_9856_ac87a32cd560row9_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 99.6%, transparent 99.6%);
#         }    #T_6d9657ec_ba94_11e9_9856_ac87a32cd560row10_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 37.3%, transparent 37.3%);
#         }    #T_6d9657ec_ba94_11e9_9856_ac87a32cd560row11_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 28.8%, transparent 28.8%);
#         }    #T_6d9657ec_ba94_11e9_9856_ac87a32cd560row12_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 53.7%, transparent 53.7%);
#         }    #T_6d9657ec_ba94_11e9_9856_ac87a32cd560row13_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 46.9%, transparent 46.9%);
#         }    #T_6d9657ec_ba94_11e9_9856_ac87a32cd560row14_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.8%, transparent 4.8%);
#         }    #T_6d9657ec_ba94_11e9_9856_ac87a32cd560row15_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.2%, transparent 12.2%);
#         }    #T_6d9657ec_ba94_11e9_9856_ac87a32cd560row16_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.3%, transparent 0.3%);
#         }    #T_6d9657ec_ba94_11e9_9856_ac87a32cd560row17_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.3%, transparent 10.3%);
#         }    #T_6d9657ec_ba94_11e9_9856_ac87a32cd560row18_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 22.7%, transparent 22.7%);
#         }    #T_6d9657ec_ba94_11e9_9856_ac87a32cd560row19_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 33.8%, transparent 33.8%);
#         }    #T_6d9657ec_ba94_11e9_9856_ac87a32cd560row20_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.3%, transparent 3.3%);
#         }    #T_6d9657ec_ba94_11e9_9856_ac87a32cd560row21_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.5%, transparent 2.5%);
#         }    #T_6d9657ec_ba94_11e9_9856_ac87a32cd560row22_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.3%, transparent 1.3%);
#         }    #T_6d9657ec_ba94_11e9_9856_ac87a32cd560row23_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.7%, transparent 0.7%);
#         }    #T_6d9657ec_ba94_11e9_9856_ac87a32cd560row24_col2 {
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_6d9657ec_ba94_11e9_9856_ac87a32cd560" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >field</th>        <th class="col_heading level0 col1" >count</th>        <th class="col_heading level0 col2" >proportion</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6d9657ec_ba94_11e9_9856_ac87a32cd560level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6d9657ec_ba94_11e9_9856_ac87a32cd560row0_col0" class="data row0 col0" >id</td>
#                         <td id="T_6d9657ec_ba94_11e9_9856_ac87a32cd560row0_col1" class="data row0 col1" >86679</td>
#                         <td id="T_6d9657ec_ba94_11e9_9856_ac87a32cd560row0_col2" class="data row0 col2" >100.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_6d9657ec_ba94_11e9_9856_ac87a32cd560level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6d9657ec_ba94_11e9_9856_ac87a32cd560row1_col0" class="data row1 col0" >type</td>
#                         <td id="T_6d9657ec_ba94_11e9_9856_ac87a32cd560row1_col1" class="data row1 col1" >86679</td>
#                         <td id="T_6d9657ec_ba94_11e9_9856_ac87a32cd560row1_col2" class="data row1 col2" >100.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_6d9657ec_ba94_11e9_9856_ac87a32cd560level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_6d9657ec_ba94_11e9_9856_ac87a32cd560row2_col0" class="data row2 col0" >title</td>
#                         <td id="T_6d9657ec_ba94_11e9_9856_ac87a32cd560row2_col1" class="data row2 col1" >86463</td>
#                         <td id="T_6d9657ec_ba94_11e9_9856_ac87a32cd560row2_col2" class="data row2 col2" >99.75%</td>
#             </tr>
#             <tr>
#                         <th id="T_6d9657ec_ba94_11e9_9856_ac87a32cd560level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_6d9657ec_ba94_11e9_9856_ac87a32cd560row3_col0" class="data row3 col0" >_meta</td>
#                         <td id="T_6d9657ec_ba94_11e9_9856_ac87a32cd560row3_col1" class="data row3 col1" >86679</td>
#                         <td id="T_6d9657ec_ba94_11e9_9856_ac87a32cd560row3_col2" class="data row3 col2" >100.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_6d9657ec_ba94_11e9_9856_ac87a32cd560level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_6d9657ec_ba94_11e9_9856_ac87a32cd560row4_col0" class="data row4 col0" >additionalType</td>
#                         <td id="T_6d9657ec_ba94_11e9_9856_ac87a32cd560row4_col1" class="data row4 col1" >86652</td>
#                         <td id="T_6d9657ec_ba94_11e9_9856_ac87a32cd560row4_col2" class="data row4 col2" >99.97%</td>
#             </tr>
#             <tr>
#                         <th id="T_6d9657ec_ba94_11e9_9856_ac87a32cd560level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_6d9657ec_ba94_11e9_9856_ac87a32cd560ro

# %% [markdown]
# ## Nested data

# %% [markdown]
# One thing you might note is that some of the fields contain nested JSON arrays or objects. For example `additionalType` contains a list of object types, while `extent` is a dictionary with keys and values. Let's unpack these columns for the second row (index of 1).

# %%
df['additionalType'][1][0]
# Out:
# 'Shoes'

# %%
df['extent'][1]
# Out:
# {'type': 'Measurement',
#  'length': 260,
#  'width': 120,
#  'depth': 40,
#  'unitText': 'mm'}

# %%
df['extent'][1]['length']
# Out:
# 260

# %% [markdown]
# ## The `additionalType` field

# %% [markdown]
# How many objects have values in the `additionalType` column?

# %%
df.loc[df['additionalType'].notnull()].shape
# Out:
# (86652, 25)

# %%
print('{:%} of objects have an additionalType value'.format(df.loc[df['additionalType'].notnull()].shape[0] / df.shape[0]))
# Out:
# 99.968851% of objects have an additionalType value

# %% [markdown]
# So which ones don't have an `additionalType`?

# %%
# Just show the first 5 rows
df.loc[df['additionalType'].isnull()].head()
# Out:
#           id    type                                              title  \
# 0     145400  object  Wahlo and Tribal law by Kevin Gilbert, reprint...
# 2     124081  object                           Pair of ceremonial shoes
# 1054  224632  object  Glass plate negative of family and horse stand...
# 1276  180161  object                 Awelye- panel 1 by Lily Kngwarreye
# 2333  180168  object                 Awelye- panel 5 by Lily Kngwarreye
#
#                                                   _meta additionalType  \
# 0     {'modified': '2018-07-09', 'issued': '2011-10-...            NaN
# 2     {'modified': '2018-12-04', 'issued': '2006-10-...            NaN
# 1054                   {'copyright': '', 'licence': ''}            NaN
# 1276                   {'copyright': '', 'licence': ''}            NaN
# 2333                   {'copyright': '', 'licence': ''}            NaN
#
#                                              collection      identifier  \
# 0                                                   NaN             NaN
# 2     {'id': '1892', 'type': 'Collection', 'title': ...  1992.0089.0165
# 1054                                                NaN             NaN
# 1276                                                NaN             NaN
# 2333                                                NaN             NaN
#
#                                           medium  \
# 0                                            NaN
# 2     [{'type': 'Material', 'title': 'Feather'}]
# 1054                                         NaN
# 1276                                         NaN
# 2333                                         NaN
#
#                                                  extent  \
# 0                                                   NaN
# 2     {'type': 'Measurement', 'length': 246, 'width'...
# 1054                                                NaN
# 1276                                                NaN
# 2333                                                NaN
#
#                                     physicalDescription  ... isPartOf seeAlso  \
# 0                                                   NaN  ...      NaN     NaN
# 2     A pair of ceremonial shoes made with several m...  ...      NaN     NaN
# 1054                                                NaN  ...      NaN     NaN
# 1276                                                NaN  ...      NaN     NaN
# 2333                                                NaN  ...      NaN     NaN
#
#      description hasVersion temporal relation hasPart location  \
# 0            NaN        NaN      NaN      NaN     NaN      NaN
# 2            NaN        NaN      NaN      NaN     NaN      NaN
# 1054         NaN        NaN      NaN      NaN     NaN      NaN
# 1276         NaN        NaN      NaN      NaN     NaN      NaN
# 2333         NaN        NaN      NaN      NaN     NaN      NaN
#
#      acknowledgement educationalSignificance
# 0                NaN                     NaN
# 2                NaN                     NaN
# 1054             NaN                     NaN
# 1276             NaN                     NaN
# 2333             NaN                     NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# How many rows have more than one `additionalType`?

# %%
df.loc[df['additionalType'].str.len() > 1].shape[0]
# Out:
# 1037

# %% [markdown]
# Let's have a look at a sample.

# %%
df.loc[df['additionalType'].str.len() > 1].head()
# Out:
#          id    type                                              title  \
# 45   202601  object                       Album of Newspaper clippings
# 118  223557  object         Receipt issued to Tirranna Race Club, 1878
# 155  227915  object                      Two toned ceramic toy tea set
# 173  256766  object  Handmade wolf figurine in yellow dress likely ...
# 564  224635  object                      Photograph of'Freda Mitchell'
#
#                                                  _meta  \
# 45   {'modified': '2019-04-22', 'issued': '2010-11-...
# 118  {'modified': '2019-04-23', 'issued': '2017-11-...
# 155  {'modified': '2019-05-17', 'issued': '2018-08-...
# 173  {'modified': '2018-12-13', 'issued': '2018-10-...
# 564  {'modified': '2019-07-01', 'issued': '2018-11-...
#
#                        additionalType  \
# 45      [Albums, Newspaper clippings]
# 118              [Invoices, Receipts]
# 155          [Tea sets, Toy tea sets]
# 173              [Novelty toys, Toys]
# 564  [Photographs, Sepia photographs]
#
#                                             collection          identifier  \
# 45   {'id': '4760', 'type': 'Collection', 'title': ...      1989.0009.0108
# 118  {'id': '6139', 'type': 'Collection', 'title': ...      2012.0019.0170
# 155  {'id': '6773', 'type': 'Collection', 'title': ...      2013.0038.0255
# 173  {'id': '6773', 'type': 'Collection', 'title': ...  2013.0038.0556.005
# 564  {'id': '6339', 'type': 'Collection', 'title': ...  2013.0062.0017.002
#
#                                                 medium  \
# 45   [{'type': 'Material', 'title': 'Cardboard'}, {...
# 118  [{'type': 'Material', 'title': 'Ink'}, {'type'...
# 155  [{'type': 'Material', 'title': 'Ceramic'}, {'t...
# 173  [{'type': 'Material', 'title': 'Cotton thread'...
# 564  [{'type': 'Material', 'title': 'Card'}, {'type...
#
#                                                 extent  \
# 45   {'type': 'Measurement', 'height': 345, 'width'...
# 118  {'type': 'Measurement', 'height': 114, 'width'...
# 155  {'type': 'Measurement', 'height': 15, 'diamete...
# 173  {'type': 'Measurement', 'height': 88, 'width':...
# 564  {'type': 'Measurement', 'height': 147, 'width'...
#
#                                    physicalDescription  ... isPartOf seeAlso  \
# 45   A brown textured hardback album with gold colo...  ...      NaN     NaN
# 118  A receipt handwritten on a piece of grey paper...  ...      NaN     NaN
# 155  A hand-painted ceramic toy tea set with a blue...  ...      NaN     NaN
# 173  A handmade wolf figurine robed in a yellow dre...  ...      NaN     NaN
# 564  A sepia photograph showing a young woman posin...  ...      NaN     NaN
#
#     description hasVersion                                           temporal  \
# 45          NaN        NaN  [{'type': 'Event', 'title': '1935', 'startDate...
# 118         NaN        NaN  [{'type': 'Event', 'title': '1878', 'startDate...
# 155         NaN        NaN  [{'type': 'Event', 'title': '1925 - 1935', 'st...
# 173         NaN        NaN  [{'type': 'Event', 'title': '1925 - 1935', 'st...
# 564         NaN        NaN                                                NaN
#
#     relation hasPart location  \
# 45       NaN     NaN      NaN
# 118      NaN     NaN      NaN
# 155      NaN     NaN      NaN
# 173      NaN     NaN      NaN
# 564      NaN     NaN      NaN
#
#                                        acknowledgement educationalSignificance
# 45                                                 NaN                     NaN
# 118                                                NaN                     NaN
# 155  Donated through the Australian Government’s Cu...                     NaN
# 173                                                NaN                     NaN
# 564                                                NaN                     NaN
#
# [5 rows x 25 columns]

# %% [markdown]
# The `additionalType` field contains a nested list of values. Using `json_normalize()` or `explode()` we can explode these lists, creating a row for each separate value.

# %%
# Use json_normalize to expand 'additionalType' into separate rows, adding the id and title from the parent record
# df_types = json_normalize(df.loc[df['additionalType'].notnull()].to_dict('records'), record_path='additionalType', meta=['id', 'title'], errors='ignore').rename({0: 'additionalType'}, axis=1)

# In pandas v.0.25 and above you can just use explode -- this prodices the same result as above
df_types = df.loc[df['additionalType'].notnull()][['id', 'title', 'additionalType']].explode('additionalType')

df_types.head()
# Out:
#        id                                              title   additionalType
# 1  251390    Pair of woven shoes made from feathers and hair            Shoes
# 3   21507                                     Grinding stone  Grinding stones
# 4  142308                                'time CHange' [sic]    Compact discs
# 5   20174    Ten Days To Live - A supposed sorcery painting.   Bark paintings
# 6  144359  'The Dance of Life (1898-1902)' by Diana Boyer...         Booklets

# %% [markdown]
# Now that we've exploded the type values, we can aggregate them in different ways. Let's look at the 25 most common object types!

# %%
df_types['additionalType'].value_counts()[:25]
# Out:
# Mineral samples                   6000
# Photographs                       4747
# Stone artefacts                   4364
# Photographic postcards            4250
# Drawings                          3759
# Postcards                         3697
# Zoological specimens              2168
# Bark paintings                    2110
# Geological specimens              1993
# Cartoons                          1535
# Engravings                        1495
# Negatives                         1124
# Boomerangs                        1025
# Spears                            1012
# Percussion and abrading stones     982
# Paintings                          840
# Clubs                              747
# Mounts                             745
# Cards                              709
# Armbands                           649
# Shells                             563
# Letters                            542
# Documents                          517
# Geophysical survey equipment       509
# Posters                            495
# Name: additionalType, dtype: int64

# %% [markdown]
# How many object types only appear once?

# %%
type_counts = df_types['additionalType'].value_counts().to_frame().reset_index().rename({'index': 'type', 'additionalType': 'count'}, axis=1)
unique_types = type_counts.loc[type_counts['count'] == 1]
unique_types.shape[0]
# Out:
# 639

# %%
unique_types.head()
# Out:
#                       type  count
# 1852   Genealogical charts      1
# 1853              Skivvies      1
# 1854         Shopping bags      1
# 1855            Jam spoons      1
# 1856  Architectural models      1

# %% [markdown]
# Let's save the complete list of types as a CSV file.

# %%
type_counts.to_csv('nma_object_type_counts.csv', index=False)
display(FileLink('nma_object_type_counts.csv'))
# Out:
# /Volumes/Workspace/mycode/glam-workbench/national-museum-australia/notebooks/nma_object_type_counts.csv

# %% [markdown]
# Browsing the CSV I noticed that there was one item with the type `Vegetables`. Let's find some more out about it.

# %%
# Find in the complete data set
mask = df.loc[df['additionalType'].notnull()]['additionalType'].apply(lambda x: 'Vegetables' in x)
veggie = df.loc[df['additionalType'].notnull()][mask]
veggie
# Out:
#            id    type                  title  \
# 63775  256742  object  Wooden toy toad stalk
#
#                                                    _meta      additionalType  \
# 63775  {'modified': '2019-04-24', 'issued': '2018-10-...  [Toys, Vegetables]
#
#                                               collection      identifier  \
# 63775  {'id': '6773', 'type': 'Collection', 'title': ...  2013.0038.0540
#
#                                                   medium  \
# 63775  [{'type': 'Material', 'title': 'Paint - non sp...
#
#                                                   extent  \
# 63775  {'type': 'Measurement', 'height': 65, 'diamete...
#
#                                      physicalDescription  ... isPartOf  \
# 63775  A painted wooden toy toad stalk with a red cap...  ...      NaN
#
#       seeAlso description hasVersion  \
# 63775     NaN         NaN        NaN
#
#                                                 temporal relation hasPart  \
# 63775  [{'type': 'Event', 'title': '1925 - 1935', 'st...      NaN     NaN
#
#       location acknowledgement educationalSignificance
# 63775      NaN             NaN                     NaN
#
# [1 rows x 25 columns]

# %% [markdown]
# We can create a link into the NMA Collections Explorer using the object `id`.

# %%
display(HTML('<a href="http://collectionsearch.nma.gov.au/?object={}">{}</a>'.format(veggie.iloc[0]['id'], veggie.iloc[0]['title'])))
# Out:
# <a href="http://collectionsearch.nma.gov.au/?object=256742">Wooden toy toad stalk</a>

# %% [markdown]
# Does a toad stool count as a vegetable?

# %% [markdown]
# ## The `extent` field
#
# The `extent` field is a nested object, so once again we'll use `json_normalize()` to expand it out into separate columns.

# %%
# Without reset_index() the rows are misaligned
df_extent = df.loc[df['extent'].notnull()].reset_index().join(json_normalize(df.loc[df['extent'].notnull()]['extent'].tolist()).add_prefix("extent_"))
df_extent.head()
# Out:
#    index      id    type                                              title  \
# 0      1  251390  object    Pair of woven shoes made from feathers and hair
# 1      2  124081  object                           Pair of ceremonial shoes
# 2      5   20174  object    Ten Days To Live - A supposed sorcery painting.
# 3      6  144359  object  'The Dance of Life (1898-1902)' by Diana Boyer...
# 4      8   42084  object  Child's drawing by Lester Moran, Cabbage Tree ...
#
#                                                _meta    additionalType  \
# 0  {'modified': '2019-01-17', 'issued': '2018-04-...           [Shoes]
# 1  {'modified': '2018-12-04', 'issued': '2006-10-...               NaN
# 2  {'modified': '2019-04-21', 'issued': '2013-06-...  [Bark paintings]
# 3  {'modified': '2018-06-18', 'issued': '2012-06-...        [Booklets]
# 4  {'modified': '2019-04-07', 'issued': '2016-10-...        [Drawings]
#
#                                           collection          identifier  \
# 0  {'id': '5244', 'type': 'Collection', 'title': ...      2000.0014.0495
# 1  {'id': '1892', 'type': 'Collection', 'title': ...      1992.0089.0165
# 2  {'id': '2202', 'type': 'Collection', 'title': ...      1985.0246.0077
# 3  {'id': '3893', 'type': 'Collection', 'title': ...  2008.0043.0022.001
# 4  {'id': '2261', 'type': 'Collection', 'title': ...      1991.0024.0027
#
#                                               medium  \
# 0  [{'type': 'Material', 'title': 'Feather'}, {'t...
# 1         [{'type': 'Material', 'title': 'Feather'}]
# 2  [{'type': 'Material', 'title': 'Bark'}, {'type...
# 3  [{'type': 'Material', 'title': 'Paper'}, {'typ...
# 4  [{'type': 'Material', 'title': 'Paint - non sp...
#
#                                               extent  ...  \
# 0  {'type': 'Measurement', 'length': 260, 'width'...  ...
# 1  {'type': 'Measurement', 'length': 246, 'width'...  ...
# 2  {'type': 'Measurement', 'length': 574, 'width'...  ...
# 3  {'type': 'Measurement', 'height': 214, 'width'...  ...
# 4  {'type': 'Measurement', 'length': 560, 'width'...  ...
#
#   educationalSignificance  extent_type extent_length extent_width  \
# 0                     NaN  Measurement         260.0        120.0
# 1                     NaN  Measurement         246.0        190.0
# 2                     NaN  Measurement         574.0        185.0
# 3                     NaN  Measurement           NaN        150.0
# 4                     NaN  Measurement         560.0        380.0
#
#   extent_depth extent_unitText extent_height extent_diameter extent_weight  \
# 0         40.0              mm           NaN             NaN           NaN
# 1         45.0              mm           NaN             NaN           NaN
# 2          NaN              mm           NaN             NaN           NaN
# 3          5.0              mm         214.0             NaN           NaN
# 4          0.5              mm           NaN             NaN           NaN
#
#   extent_unitTextWeight
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#
# [5 rows x 35 columns]

# %% [markdown]
# Let's check to see what types of things are in the `extent` field.

# %%
df_extent['extent_type'].value_counts()
# Out:
# Measurement    64077
# Name: extent_type, dtype: int64

# %% [markdown]
# So they're all measurements. Let's have a look at the units being used.

# %%
df_extent['extent_unitText'].value_counts()
# Out:
# mm    63382
# MM       10
# cm        9
# m         5
# Name: extent_unitText, dtype: int64

# %%
df_extent['extent_unitTextWeight'].value_counts()
# Out:
# g        1473
# kg        209
# lb          5
# oz          4
# tonne       1
# Name: extent_unitTextWeight, dtype: int64

# %% [markdown]
# Hmmm, are those measurements really in metres, or might they be meant to be 'mm'? Let's have a look at them.

# %%
df_extent.loc[df_extent['extent_unitText'] == 'm'][['id', 'title', 'extent_length', 'extent_width', 'extent_unitText']]
# Out:
#            id                                              title  \
# 16781  202783  The Percival Project, Gull Twelve, in a manill...
# 18291  214193                                     Extension tube
# 41612  123962                                     Gunter's chain
# 47232  171768                                        Fair Breeze
# 56789  257184                       Fishing line inside envelope
#
#        extent_length  extent_width extent_unitText
# 16781            NaN         230.0               m
# 18291        55.0000           NaN               m
# 41612        20.1168           NaN               m
# 47232            NaN         138.0               m
# 56789       137.0000         110.0               m

# %% [markdown]
# Other than 'Gunter's chain' it looks like the unit should indeed by 'mm'. We'll need to take that into account in calculations.
#
# Now let's convert all the measurements into a single unit – millimetre for lengths, and gram for weights.

# %%
def conversion_factor(unit):
    '''
    Get the factor required to convery current unit to either mm or g.
    '''
    factors = {
        'mm': 1,
        'cm': 10,
        'm': 1, # Most should in fact be mm (see above)
        'g': 1,
        'kg': 1000,
        'tonne': 1000000,
        'oz': 28.35,
        'lb': 453.592
    }
    try:
        factor = factors[unit.lower()]
    except KeyError:
        factor = 0 
    return factor

def normalise_measurements(row):
    '''
    Convert measurements to standard units.
    '''
    l_factor = conversion_factor(str(row['extent_unitText']))
    length = row['extent_length'] * l_factor
    width = row['extent_width'] * l_factor
    depth = row['extent_depth'] * l_factor
    height = row['extent_height'] * l_factor
    diameter = row['extent_diameter'] * l_factor
    w_factor = conversion_factor(str(row['extent_unitTextWeight']))
    weight = row['extent_weight'] * w_factor
    return pd.Series([length, width, depth, height, diameter, weight])

# Add normalised measurements to the dataframe
df_extent[['length_mm', 'width_mm', 'depth_mm', 'height_mm', 'diameter_mm', 'weight_g']] = df_extent.apply(normalise_measurements, axis=1)

# %%
df_extent.head()
# Out:
#    index      id    type                                              title  \
# 0      1  251390  object    Pair of woven shoes made from feathers and hair
# 1      2  124081  object                           Pair of ceremonial shoes
# 2      5   20174  object    Ten Days To Live - A supposed sorcery painting.
# 3      6  144359  object  'The Dance of Life (1898-1902)' by Diana Boyer...
# 4      8   42084  object  Child's drawing by Lester Moran, Cabbage Tree ...
#
#                                                _meta    additionalType  \
# 0  {'modified': '2019-01-17', 'issued': '2018-04-...           [Shoes]
# 1  {'modified': '2018-12-04', 'issued': '2006-10-...               NaN
# 2  {'modified': '2019-04-21', 'issued': '2013-06-...  [Bark paintings]
# 3  {'modified': '2018-06-18', 'issued': '2012-06-...        [Booklets]
# 4  {'modified': '2019-04-07', 'issued': '2016-10-...        [Drawings]
#
#                                           collection          identifier  \
# 0  {'id': '5244', 'type': 'Collection', 'title': ...      2000.0014.0495
# 1  {'id': '1892', 'type': 'Collection', 'title': ...      1992.0089.0165
# 2  {'id': '2202', 'type': 'Collection', 'title': ...      1985.0246.0077
# 3  {'id': '3893', 'type': 'Collection', 'title': ...  2008.0043.0022.001
# 4  {'id': '2261', 'type': 'Collection', 'title': ...      1991.0024.0027
#
#                                               medium  \
# 0  [{'type': 'Material', 'title': 'Feather'}, {'t...
# 1         [{'type': 'Material', 'title': 'Feather'}]
# 2  [{'type': 'Material', 'title': 'Bark'}, {'type...
# 3  [{'type': 'Material', 'title': 'Paper'}, {'typ...
# 4  [{'type': 'Material', 'title': 'Paint - non sp...
#
#                                               extent  ... extent_height  \
# 0  {'type': 'Measurement', 'length': 260, 'width'...  ...           NaN
# 1  {'type': 'Measurement', 'length': 246, 'width'...  ...           NaN
# 2  {'type': 'Measurement', 'length': 574, 'width'...  ...           NaN
# 3  {'type': 'Measurement', 'height': 214, 'width'...  ...         214.0
# 4  {'type': 'Measurement', 'length': 560, 'width'...  ...           NaN
#
#   extent_diameter extent_weight extent_unitTextWeight length_mm width_mm  \
# 0             NaN           NaN                   NaN     260.0    120.0
# 1             NaN           NaN                   NaN     246.0    190.0
# 2             NaN           NaN                   NaN     574.0    185.0
# 3             NaN           NaN                   NaN       NaN    150.0
# 4             NaN           NaN                   NaN     560.0    380.0
#
#   depth_mm height_mm diameter_mm weight_g
# 0     40.0       NaN         NaN      NaN
# 1     45.0       NaN         NaN      NaN
# 2      NaN       NaN         NaN      NaN
# 3      5.0     214.0         NaN      NaN
# 4      0.5       NaN         NaN      NaN
#
# [5 rows x 41 columns]

# %% [markdown]
# ## How big is the collection?

# %%
def calculate_volume(row):
    '''
    Look for 3 linear dimensions and multiply them to get a volume.
    '''
    # Create a list of valid linear measurements from the available fields
    dimensions = [d for d in [row['length_mm'], row['width_mm'], row['depth_mm'], row['height_mm'], row['diameter_mm']] if not math.isnan(d)]
    
    # If there's only 2 dimensions...
    if len(dimensions) == 2:
        # Set a default height of 1 for items with only 2 dimensions
        dimensions.append(1)
        
    # If there's 3 or more dimensions, multiple the first 3 together
    if len(dimensions) >= 3:
        volume = dimensions[0] * dimensions[1] * dimensions[2]
    else:
        volume = 0
    return volume

df_extent['volume'] = df_extent.apply(calculate_volume, axis=1)

# %%
print('Total length of objects is {:.2f} km'.format(df_extent['length_mm'].sum() / 1000 / 1000))
# Out:
# Total length of objects is 15.36 km

# %%
print('Total weight of objects is {:.2f} tonnes'.format(df_extent['weight_g'].sum() / 1000000))
# Out:
# Total weight of objects is 194.30 tonnes

# %%
print('Total volume of objects is {:.2f} m\N{SUPERSCRIPT THREE}'.format(df_extent['volume'].sum() / 1000000000))
# Out:
# Total volume of objects is 2873.14 m³

# %% [markdown]
# ## The biggest object?

# %% [markdown]
# What's the biggest thing?

# %%
# Get the object with the largest volume
biggest = df_extent.loc[df_extent['volume'].idxmax()]

# Create a link to Collection Explorer
display(HTML('<a href="http://collectionsearch.nma.gov.au/?object={}">{}</a>'.format(biggest['id'], biggest['title'])))
# Out:
# <a href="http://collectionsearch.nma.gov.au/?object=7272">Percival Proctor Mk 1 monoplane VH-FEP</a>

# %% [markdown]
# ----
#
# Created by [Tim Sherratt](https://timsherratt.org/) for the [GLAM Workbench](https://glam-workbench.github.io/).
#
# Work on this notebook was supported by the [Humanities, Arts and Social Sciences (HASS) Data Enhanced Virtual Lab](https://tinker.edu.au/).
